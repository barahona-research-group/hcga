# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
N= G.number_of_nodes()    
E= G.number_of_edges()

# %%
from networkx.algorithms import approximation as apxa

k_components = apxa.k_components(G)

# %%
from networkx.algorithms import centrality

# %%
#list(centrality.degree_centrality(G).values())
degree_centrality = np.asarray(list(centrality.degree_centrality(G).values()))

# %%
from hcga.Operations import DistributionFitting

DistributionFitting.best_fit_distribution(degree_centrality)
# Out:
# ('foldcauchy', (1.2175950202397146, 0.03030303027692246, 0.042814261788226074))

# %%
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-79bc994356d1> in <module>()
# ----> 1 DistributionFitting.power_law_fit(degree_centrality)
#
# /home/robert/Documents/PythonCode/hcga/hcga/Operations/DistributionFitting.py in power_law_fit(data, bins)
#      27         pass
#      28
# ---> 29     return (params, sse)
#      30
#      31
#
# UnboundLocalError: local variable 'sse' referenced before assignment

# %%
import warnings

def power_law_fit(data,bins=10):
    y, x = np.histogram(data, bins=bins)
    x = (x + np.roll(x, -1))[:-1] / 2.0
    try:
        # Ignore warnings from data that can't be fit
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore')
            params = st.powerlaw.fit(data)

            # Separate parts of parameters
            arg = params[:-2]
            loc = params[-2]
            scale = params[-1]

            # Calculate fitted PDF and error with fit in distribution
            pdf = st.powerlaw.pdf(x, loc=loc, scale=scale, *arg)
            sse = np.sum(np.power(y - pdf, 2.0))
    except Exception:
        pass

    return (params, sse)

#power_law_fit(degree_centrality)
y, x = np.histogram(degree_centrality, bins=10)
x = (x + np.roll(x, -1))[:-1] / 2.0
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-3b3c092f7154> in <module>()
#      23     return (params, sse)
#      24
# ---> 25 power_law_fit(degree_centrality)
#      26 y, x = np.histogram(degree_centrality, bins=10)
#      27 x = (x + np.roll(x, -1))[:-1] / 2.0
#
# <ipython-input-19-3b3c092f7154> in power_law_fit(data, bins)
#      21         pass
#      22
# ---> 23     return (params, sse)
#      24
#      25 power_law_fit(degree_centrality)
#
# UnboundLocalError: local variable 'sse' referenced before assignment

# %%
y
# Out:
# array([12, 12,  3,  2,  0,  2,  1,  0,  0,  2])

# %%
import scipy.stats as st
params = st.powerlaw.fit(degree_centrality)
params
# Out:
# (0.5917043194481377, 0.030303030303030297, 0.5052580308932091)
