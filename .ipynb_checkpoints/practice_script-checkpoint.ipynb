# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
import yaml

with open("hcga/Operations/operations.yaml", 'r') as stream:
    data_loaded = yaml.load(stream)

# %%
for key in data_loaded.keys():
    print(data_loaded[key])
# Out:
# hcga/operations
# INFO
# {'fileName': 'basic_stats', 'functionName': 'basic_stats', 'shortName': 'BS', 'keywords': None}
# {'fileName': 'triangles', 'functionName': 'triangle_stats', 'shortName': 'TS', 'keywords': None}
# {'fileName': 'centrality_degree', 'functionName': 'DegreeCentrality', 'shortName': 'DC', 'keywords': None, 'bins': 5}
# {'fileName': 'centrality_degree', 'functionName': 'DegreeCentrality', 'shortName': 'DC', 'keywords': None, 'bins': 10}
# {'fileName': 'centrality_degree', 'functionName': 'DegreeCentrality', 'shortName': 'DC', 'keywords': None, 'bins': 50}

# %%
from hcga.Operations import
