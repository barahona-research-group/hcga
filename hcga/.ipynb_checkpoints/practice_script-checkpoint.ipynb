# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
import Calculation.graphs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-fb27e7584f64> in <module>()
# ----> 1 import Calculation.graphs
#
# /home/robert/Documents/PythonCode/hcga/hcga/Calculation/graphs.py in <module>()
#       2 import networkx as nx
#       3
# ----> 4 import load_data
#       5
#       6 class Graphs():
#
# ModuleNotFoundError: No module named 'load_data'
