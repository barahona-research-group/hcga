# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
from hcga.Operations.operations import Operations

op = Operations(G)
op.feature_extraction()
op.feature_names
# Out:
# [['BS_num_nodes',
#   'BS_num_edges',
#   'BS_degree_mean',
#   'BS_degree_median',
#   'BS_degree_std'],
#  ['C_num_triangles',
#   'C_transitivity',
#   'C_clustering_mean',
#   'C_clustering_std',
#   'C_clustering_median',
#   'C_square_clustering_mean',
#   'C_square_clustering_std',
#   'C_square_clustering_median'],
#  ['DC_mean_10',
#   'DC_std_10',
#   'DC_opt_model_10',
#   'DC_powerlaw_a_10',
#   'DC_powerlaw_SSE_10'],
#  ['DC_mean_20',
#   'DC_std_20',
#   'DC_opt_model_20',
#   'DC_powerlaw_a_20',
#   'DC_powerlaw_SSE_20'],
#  ['DC_mean_50',
#   'DC_std_50',
#   'DC_opt_model_50',
#   'DC_powerlaw_a_50',
#   'DC_powerlaw_SSE_50'],
#  ['EC_mean_10',
#   'EC_std_10',
#   'EC_opt_model_10',
#   'EC_powerlaw_a_10',
#   'EC_powerlaw_SSE_10'],
#  ['EC_mean_20',
#   'EC_std_20',
#   'EC_opt_model_20',
#   'EC_powerlaw_a_20',
#   'EC_powerlaw_SSE_20'],
#  ['EC_mean_50',
#   'EC_std_50',
#   'EC_opt_model_50',
#   'EC_powerlaw_a_50',
#   'EC_powerlaw_SSE_50'],
#  ['MC_num_comms_greedy_mod']]

# %%
from hcga import graphs
graph_obj = graphs.Graphs()
graph_obj.calculate_features()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# <ipython-input-5-50ac283e8fd3> in <module>()
#       1 from hcga import graphs
#       2 graph_obj = graphs.Graphs()
# ----> 3 graph_obj.calculate_features()
#
# ~/anaconda3/lib/python3.6/site-packages/hcga/graphs.py in calculate_features(self)
#      56         for G in tqdm(self.graphs):
#      57             G_operations = Operations(G)
# ---> 58             G_operations.feature_extraction()
#      59             graph_feature_set.append(G_operations)
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/hcga/Operations/operations.py in feature_extraction(self)
#      70                 feature_obj.feature_extraction()
#      71             else:
# ---> 72                 feature_obj.feature_extraction(params)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/hcga/Operations/centrality_eigenvector.py in feature_extraction(self, args)
#      76
#      77         #Calculate the degree centrality of each node
# ---> 78         eigenvector_centrality = np.asarray(list(centrality.eigenvector_centrality(G).values()))
#      79
#      80         # Basic stats regarding the degree centrality distribution
#
# <decorator-gen-262> in eigenvector_centrality(G, max_iter, tol, nstart, weight)
#
# ~/anaconda3/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
# ---> 82             return not_implement_for_func(*args, **kwargs)
#      83     return _not_implemented_for
#      84
#
# ~/anaconda3/lib/python3.6/site-packages/networkx/algorithms/centrality/eigenvector.py in eigenvector_centrality(G, max_iter, tol, nstart, weight)
#     146         if sum(abs(x[n] - xlast[n]) for n in x) < nnodes * tol:
#     147             return x
# --> 148     raise nx.PowerIterationFailedConvergence(max_iter)
#     149
#     150
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')

# %%
from networkx.algorithms.community import greedy_modularity_communities
list(greedy_modularity_communities(G))

# %%
from networkx.algorithms.community import _naive_greedy_modularity_communities
list(_naive_greedy_modularity_communities(G))

# %%
from networkx.algorithms.community import k_clique_communities
list(k_clique_communities(G, 3))
