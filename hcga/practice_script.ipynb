# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
from hcga.Operations.
# Out:
#   File "<ipython-input-4-76c819179736>", line 1
#     from hcga.Operations.
#                          ^
# SyntaxError: invalid syntax

# %%
from hcga.Operations.operations import Operations

op = Operations(G)
op.feature_extraction()

op.feature_names
# Out:
# [['BS_num_nodes',
#   'BS_num_edges',
#   'BS_degree_mean',
#   'BS_degree_median',
#   'BS_degree_std'],
#  ['TS_num_triangles',
#   'TS_transitivity',
#   'TS_clustering_mean',
#   'TS_clustering_std',
#   'TS_clustering_median',
#   'TS_square_clustering_mean',
#   'TS_square_clustering_std',
#   'TS_square_clustering_median'],
#  ['DC_mean_10',
#   'DC_std_10',
#   'DC_opt_model_10',
#   'DC_powerlaw_a_10',
#   'DC_powerlaw_SSE_10'],
#  ['DC_mean_20',
#   'DC_std_20',
#   'DC_opt_model_20',
#   'DC_powerlaw_a_20',
#   'DC_powerlaw_SSE_20'],
#  ['DC_mean_50',
#   'DC_std_50',
#   'DC_opt_model_50',
#   'DC_powerlaw_a_50',
#   'DC_powerlaw_SSE_50'],
#  ['EC_mean_10',
#   'EC_std_10',
#   'EC_opt_model_10',
#   'EC_powerlaw_a_10',
#   'EC_powerlaw_SSE_10'],
#  ['EC_mean_20',
#   'EC_std_20',
#   'EC_opt_model_20',
#   'EC_powerlaw_a_20',
#   'EC_powerlaw_SSE_20'],
#  ['EC_mean_50',
#   'EC_std_50',
#   'EC_opt_model_50',
#   'EC_powerlaw_a_50',
#   'EC_powerlaw_SSE_50']]

# %%
from hcga import graphs

# %%
graph_obj = graphs.Graphs()

# %%
graph_obj.calculate_features()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-4d3dbc60d6ff> in <module>()
# ----> 1 graph_obj.calculate_features()
#
# /home/robert/anaconda3/lib/python3.6/site-packages/hcga/graphs.py in calculate_features(self)
#      49         for G in tqdm(self.graphs):
#      50             G_operations = Operations(G)
# ---> 51             G_operations.feature_extraction()
#      52             graph_feature_set.append(G_operations)
#      53
#
# /home/robert/anaconda3/lib/python3.6/site-packages/hcga/Operations/operations.py in feature_extraction(self)
#      64
#      65             # import the class from the file
# ---> 66             feature_obj = getattr(import_module('hcga.Operations.'+filename), classname)
#      67             feature_obj = feature_obj(self.G)
#      68
#
# /home/robert/anaconda3/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /home/robert/anaconda3/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /home/robert/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /home/robert/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'hcga.Operations.centrality_eigenvector'

# %%
import scipy.stats as st
DISTRIBUTIONS = [st.powerlaw, st.expon, st.norm, st.lognorm, st.beta]
distribution = st.norm

DISTRIBUTIONS.index(st.norm)
# Out:
# 2

# %%
distribution.name
# Out:
# 'norm'
