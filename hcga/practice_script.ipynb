# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



# %matplotlib notebook

# %%
G = nx.karate_club_graph()

# %%
plt.figure()
nx.draw_networkx(G)

# %%
from hcga.Operations.operations import Operations

op = Operations(G)

# %%
op.feature_extraction()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  60%|██████    | 3/5 [00:00<00:00,  9.36it/s]
#  80%|████████  | 4/5 [00:00<00:00,  7.86it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.01it/s]

# %%
op.feature_names
# Out:
# [['BS_num_nodes',
#   'BS_num_edges',
#   'BS_degree_mean',
#   'BS_degree_median',
#   'BS_degree_std'],
#  ['TS_num_triangles',
#   'TS_transitivity',
#   'TS_clustering_mean',
#   'TS_clustering_std',
#   'TS_clustering_median',
#   'TS_square_clustering_mean',
#   'TS_square_clustering_std',
#   'TS_square_clustering_median'],
#  ['DC_mean_10',
#   'DC_std_10',
#   'DC_opt_model_10',
#   'DC_powerlaw_a_10',
#   'DC_powerlaw_SSE_10'],
#  ['DC_mean_20',
#   'DC_std_20',
#   'DC_opt_model_20',
#   'DC_powerlaw_a_20',
#   'DC_powerlaw_SSE_20'],
#  ['DC_mean_50',
#   'DC_std_50',
#   'DC_opt_model_50',
#   'DC_powerlaw_a_50',
#   'DC_powerlaw_SSE_50']]

# %%
from hcga import graphs

# %%
graph_obj = graphs.Graphs()

# %%
graph_obj.calculate_features()
# Out:
# Graph loop:   0%|          | 0/600 [00:00<?, ?it/s]
# TqdmDeprecationWarning: `nested` is deprecated and automated. Use position instead for manual control.
# ---------------------------------------------------------------------------
# TqdmDeprecationWarning                    Traceback (most recent call last)
# <ipython-input-3-4d3dbc60d6ff> in <module>()
# ----> 1 graph_obj.calculate_features()
#
# /home/robert/anaconda3/lib/python3.6/site-packages/hcga/graphs.py in calculate_features(self)
#      49         for G in tqdm(self.graphs,desc='Graph loop',leave=True):
#      50             G_operations = Operations(G)
# ---> 51             G_operations.feature_extraction()
#      52             graph_feature_set.append(G_operations)
#      53
#
# /home/robert/anaconda3/lib/python3.6/site-packages/hcga/Operations/operations.py in feature_extraction(self)
#      48
#      49         # loop over the feature classes defined in the YAML file
# ---> 50         for key in tqdm(operations_dict.keys(),desc='Feature extraction',leave=True,nested=True):
#      51             operation = operations_dict[key]
#      52
#
# /home/robert/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py in __init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, gui, **kwargs)
#     777 `nested` is deprecated and automated. Use position instead for manual control.
#     778 """, fp_write=getattr(file, 'write', sys.stderr.write)) if "nested" in kwargs
# --> 779                 else TqdmKeyError("Unknown argument(s): " + str(kwargs)))
#     780
#     781         # Preprocess the arguments
#
# TqdmDeprecationWarning: `nested` is deprecated and automated. Use position instead for manual control.

# %%
new = graph_obj.calculated_graph_features[0]

# %%
new.feature_vals
# Out:
# [[37, 84, 18.0, 18.0, 10.677078252031311],
#  [4.297297297297297,
#   0.5047619047619047,
#   0.5653796653796652,
#   0.17398229683927313,
#   0.5333333333333333,
#   0.2269781191959365,
#   0.19466621848404464,
#   0.1956521739130435],
#  [0.12612612612612611,
#   0.027089517346349422,
#   'lognorm',
#   0.08333333333333331,
#   426.1419236964868],
#  [0.12612612612612611,
#   0.027089517346349422,
#   'norm',
#   0.08333333333333331,
#   1242.9032180686183],
#  [0.12612612612612611,
#   0.027089517346349422,
#   'lognorm',
#   0.08333333333333331,
#   5906.518278524067]]

# %%
new.feature_names
# Out:
# [['BS_num_nodes',
#   'BS_num_edges',
#   'BS_degree_mean',
#   'BS_degree_median',
#   'BS_degree_std'],
#  ['TS_num_triangles',
#   'TS_transitivity',
#   'TS_clustering_mean',
#   'TS_clustering_std',
#   'TS_clustering_median',
#   'TS_square_clustering_mean',
#   'TS_square_clustering_std',
#   'TS_square_clustering_median'],
#  ['mean_10', 'std_10', 'opt_model_10', 'powerlaw_a_10', 'powerlaw_SSE_10'],
#  ['mean_20', 'std_20', 'opt_model_20', 'powerlaw_a_20', 'powerlaw_SSE_20'],
#  ['mean_50', 'std_50', 'opt_model_50', 'powerlaw_a_50', 'powerlaw_SSE_50']]
