# %% [markdown]
# # Custom Data Example

# %%
import numpy as np
import networkx as nx
import pandas as pd
import scipy as sc

# %%
# this cell is generating some synthetic graph dataset with node features. 


#defining limits on number of nodes
n_min = 20
n_max = 50

#number of graphs
num_g = 50 

# number of node features - in this example I will generate random node features that aren't useful for classifcation
n_nf = 3


# empty list of graphs and labels
graphs = []
labels = []
node_features = []


# setting limits on probability of edge existing for random graphs
p_min = 0.05
p_max = 0.9

# adding 50 random graphs and adding the label corresponding to probability of edge existing
for i in range(num_g):
    rand_n = np.random.randint(n_min,n_max)
    rand_p = np.random.randint(int(p_min*100),int(p_max*100))/100   
    
    g = nx.fast_gnp_random_graph(rand_n,rand_p)    
    node_feat_matrix = np.random.random((rand_n,n_nf))
    
    graphs.append(nx.to_numpy_array(g))
    node_features.append(node_feat_matrix)
    
    labels.append(rand_p)

# %% [markdown]
# We now have three lists of length 100. The graphs list is composed of numpy arrays that represent the adjacency matrix of the graph. The node features list is composed of numpy arrays that contain the node information for each graph. The labels list is a list of integers that corresponds to the class label for each graph.
#
# The next step is to take this data and convert it into an appropriate format for hcga.

# %%
# converting this data into the format required for hcga

from hcga.graph import Graph, GraphCollection

# create graph collection object
g_c = GraphCollection()


# looping over each graph and appending it to the graph collection object
for i,A in enumerate(graphs):
    
    # generating a sparse matrix
    sA = sc.sparse.coo_matrix(A)
    
    # extracting edge list from scipy sparse matrix
    edges = np.array([sA.row,sA.col,sA.data]).T
    
    # passing edge list to pandas dataframe
    edges_df = pd.DataFrame(edges, columns = ['start_node', 'end_node', 'weight'])

    # creating node ids based on size of adjancency matrix
    nodes = np.arange(0,A.shape[0])
    
    # loading node ids into dataframe
    nodes_df = pd.DataFrame(index=nodes)

    # each node should have the same number of node features across all graphs
    # converting node features array to list such that each node is assigned a list.
    nodes_df['attributes'] = node_features[i].tolist()

    # extracting graph label from labels
    graph_label = [labels[i]]
    
    # create a single graph object
    graph = Graph(nodes_df, edges_df, graph_label, 'p_edge')

    # add new graph to the collection
    g_c.add_graph(graph)

# %%
# perform some sanity checks

print('There are {} graphs'.format(len(g_c.graphs)))
print('There are {} features per node'.format(g_c.get_n_node_features()))
# Out:
# There are 50 graphs
# There are 3 features per node

# %%
# we can save this if we want to and run everything from the command line
from hcga.io import save_dataset

save_dataset(g_c, 'custom_dataset_regression', folder='./datasets')

# %% [markdown]
# # Extracting features
#
# We have now produced a pickle dataset of your own custom data. We can now run the feature extraction from the command line using the following commands:
#
# hcga extract_features ./datasets/custom_dataset.pkl -m fast -n 4 -sl advanced --timeout 10
#
#
# Alternatively,we could import the Hcga class and run the feature extraction and analysis from within the notebook. We will do this below.

# %%
from hcga.io import load_dataset

graphs = load_dataset('./datasets/custom_dataset_regression.pkl')

# %%
#import hcga object
from hcga.hcga import Hcga

# define an object
h = Hcga()

#assigning the graphs field to the recently created dataset
h.graphs = graphs

# %%
# extracting all features here
h.extract(mode='fast',n_workers=4,timeout=2)
# Out:
# Returning the maximal subgraph for each graph
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# An input array is constant; the correlation coefficent is not defined.
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# Extracting features from 50 graphs (we disabled 0 graphs).
# Computing features for 50 graphs:
#   0%|          | 0/50 [00:00<?, ?it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#   2%|▏         | 1/50 [00:02<02:15,  2.76s/it]divide by zero encountered in double_scalars
#   4%|▍         | 2/50 [00:03<01:44,  2.17s/it]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature local_efficiency for graph 3 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#   6%|▌         | 3/50 [00:05<01:35,  2.02s/it]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in double_scalars
#   8%|▊         | 4/50 [00:06<01:15,  1.65s/it]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 3 took longer than 2 seconds
# divide by zero encountered in double_scalars
#  10%|█         | 5/50 [00:06<01:04,  1.44s/it]divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  12%|█▏        | 6/50 [00:07<00:51,  1.17s/it]Mean of empty slice.
# invalid value encountered in double_scalars
#  14%|█▍        | 7/50 [00:07<00:38,  1.11it/s]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature clique_sizes for graph 3 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
#  16%|█▌        | 8/50 [00:09<00:45,  1.09s/it]divide by zero encountered in log
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  18%|█▊        | 9/50 [00:10<00:44,  1.09s/it]Mean of empty slice.
# invalid value encountered in double_scalars
#  20%|██        | 10/50 [00:10<00:33,  1.19it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature local_efficiency for graph 9 took longer than 2 seconds
# divide by zero encountered in double_scalars
#  22%|██▏       | 11/50 [00:11<00:36,  1.05it/s]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  24%|██▍       | 12/50 [00:12<00:32,  1.18it/s]Mean of empty slice.
# DEBUG:Feature exceptions:Feature local_efficiency for graph 11 took longer than 2 seconds
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 17 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 17 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
# invalid value encountered in double_scalars
#  26%|██▌       | 13/50 [00:13<00:35,  1.04it/s]DEBUG:Feature exceptions:Feature num_cliques for graph 9 took longer than 2 seconds
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature edge betweenness centrality_hmean for graph 17 with exception: Harmonic mean only defined if all elements greater than or equal to zero
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# Degrees of freedom <= 0 for slice
# invalid value encountered in true_divide
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 17 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature num_communities for graph 17 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature largest_commsize for graph 17 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature ratio_commsize_maxmin for graph 17 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature communities for graph 17 with exception: float division by zero
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature clique_sizes_min for graph 17 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature clique_sizes_max for graph 17 with exception: zero-size array to reduction operation maximum which has no identity
# invalid value encountered in true_divide
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_mode for graph 17 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstat for graph 17 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstatvar for graph 17 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmin for graph 17 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmax for graph 17 with exception: No array values within given limits
# Mean of empty slice.
# DEBUG:Feature exceptions:Failed feature clique_sizes_maximal for graph 17 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_min for graph 17 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_max for graph 17 with exception: zero-size array to reduction operation maximum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_mode for graph 17 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_kstat for graph 17 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_kstatvar for graph 17 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_tmin for graph 17 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature edge_weights_tmax for graph 17 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature rich_club_k=1 for graph 17 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_k=max for graph 17 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_maxminratio for graph 17 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club for graph 17 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff for graph 17 with exception: max() arg is an empty sequence
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff_pearson for graph 17 with exception: not enough values to unpack (expected 2, got 0)
#  30%|███       | 15/50 [00:14<00:30,  1.17it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  32%|███▏      | 16/50 [00:15<00:26,  1.30it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  36%|███▌      | 18/50 [00:16<00:19,  1.62it/s]DEBUG:Feature exceptions:Feature clique_sizes for graph 9 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  38%|███▊      | 19/50 [00:17<00:22,  1.37it/s]divide by zero encountered in double_scalars
#  40%|████      | 20/50 [00:17<00:18,  1.58it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  42%|████▏     | 21/50 [00:18<00:14,  2.06it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  44%|████▍     | 22/50 [00:19<00:19,  1.42it/s]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  46%|████▌     | 23/50 [00:19<00:18,  1.44it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  48%|████▊     | 24/50 [00:20<00:20,  1.29it/s]invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in log
#  52%|█████▏    | 26/50 [00:21<00:14,  1.69it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  54%|█████▍    | 27/50 [00:21<00:10,  2.13it/s]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  56%|█████▌    | 28/50 [00:23<00:20,  1.10it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in double_scalars
#  58%|█████▊    | 29/50 [00:25<00:24,  1.18s/it]DEBUG:Feature exceptions:Feature local_efficiency for graph 28 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 29 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature local_efficiency for graph 31 took longer than 2 seconds
# divide by zero encountered in log
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 28 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature clique_sizes for graph 29 took longer than 2 seconds
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 33 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 33 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
#  60%|██████    | 30/50 [00:28<00:36,  1.83s/it]invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
#  64%|██████▍   | 32/50 [00:29<00:25,  1.43s/it]divide by zero encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature clique_sizes for graph 28 took longer than 2 seconds
#  66%|██████▌   | 33/50 [00:30<00:20,  1.20s/it]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  68%|██████▊   | 34/50 [00:30<00:16,  1.04s/it]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in log
#  70%|███████   | 35/50 [00:31<00:14,  1.07it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  72%|███████▏  | 36/50 [00:31<00:10,  1.35it/s]divide by zero encountered in log
#  74%|███████▍  | 37/50 [00:32<00:07,  1.78it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  76%|███████▌  | 38/50 [00:33<00:09,  1.28it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  78%|███████▊  | 39/50 [00:33<00:06,  1.71it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  82%|████████▏ | 41/50 [00:34<00:05,  1.69it/s]invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  84%|████████▍ | 42/50 [00:35<00:04,  1.86it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  86%|████████▌ | 43/50 [00:35<00:04,  1.72it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  88%|████████▊ | 44/50 [00:36<00:03,  1.79it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature local_efficiency for graph 43 took longer than 2 seconds
# divide by zero encountered in double_scalars
#  90%|█████████ | 45/50 [00:37<00:04,  1.23it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  92%|█████████▏| 46/50 [00:38<00:03,  1.06it/s]divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature local_efficiency for graph 46 took longer than 2 seconds
#  94%|█████████▍| 47/50 [00:39<00:02,  1.19it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 47 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature num_cliques for graph 46 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature clique_sizes for graph 47 took longer than 2 seconds
# divide by zero encountered in double_scalars
#  96%|█████████▌| 48/50 [00:43<00:03,  1.74s/it]DEBUG:Feature exceptions:Feature num_cliques for graph 49 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature clique_sizes for graph 46 took longer than 2 seconds
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  98%|█████████▊| 49/50 [00:44<00:01,  1.67s/it]DEBUG:Feature exceptions:Feature clique_sizes for graph 49 took longer than 2 seconds
# divide by zero encountered in double_scalars
# 100%|██████████| 50/50 [00:46<00:00,  1.08it/s]
# 628 feature extracted.
# 432 valid features.

# %%
# saving all features into a pickle
h.save_features('./results/custom_dataset_regression/all_features.pkl')

# %% [markdown]
# # Analysis - regression  example

# %%
# load the saved features

h.load_features('./results/custom_dataset_regression/all_features.pkl')

# %%
# implement a classification analyse of the features
h.analyse_features(feature_file='./results/custom_dataset_regression/all_features.pkl',
                   analysis_type='regression',
                   results_folder='./results/custom_dataset_regression')
# Out:
# INFO:hcga.analysis:628 total features
# INFO:hcga.utils:0 graphs were removed for more than 0.3 fraction of bad features
# INFO:hcga.analysis:432 valid features
# INFO:hcga.analysis:432 with interpretability 1
# INFO:hcga.analysis:... Using Xgboost regressor ...
# INFO:hcga.analysis:Using kfold
# INFO:hcga.analysis:Explained Variance: --- 0.99 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.988 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.916 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.976 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.99 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.982 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.997 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.968 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.994 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: --- 0.979 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Explained Variance: 0.978 +/- 0.022
# INFO:hcga.analysis:Now using a reduced set of 101 features with < 0.9 correlation.
# INFO:hcga.analysis:Explained Variance: --- 0.995 ---
# INFO:hcga.analysis:Explained Variance: --- 0.99 ---
# INFO:hcga.analysis:Explained Variance: --- 0.952 ---
# INFO:hcga.analysis:Explained Variance: --- 0.984 ---
# INFO:hcga.analysis:Explained Variance: --- 0.983 ---
# INFO:hcga.analysis:Explained Variance: --- 0.989 ---
# INFO:hcga.analysis:Explained Variance: --- 0.971 ---
# INFO:hcga.analysis:Explained Variance: --- 0.964 ---
# INFO:hcga.analysis:Explained Variance: --- 0.997 ---
# INFO:hcga.analysis:Explained Variance: --- 0.993 ---
# INFO:hcga.analysis:Accuracy with reduced set: 0.982 +/- 0.014
# Sample Expanded Feature Summary for Class 0
