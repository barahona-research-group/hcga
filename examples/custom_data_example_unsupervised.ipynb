# %% [markdown]
# # Custom Data Example

# %%
import numpy as np
import networkx as nx
import pandas as pd
import scipy as sc

# %%
# this cell is generating some synthetic graph dataset with node features. 


#defining limits on number of nodes
n_min = 20
n_max = 50

#number of graphs
num_g = 50 

# number of node features - in this example I will generate random node features that aren't useful for classifcation
n_nf = 3


# empty list of graphs and labels
graphs = []
labels = []
node_features = []


# setting limits on probability of edge existing for random graphs
p_min = 0.05
p_max = 0.9

# adding 50 random graphs and adding the label corresponding to probability of edge existing
for i in range(num_g):
    rand_n = np.random.randint(n_min,n_max)
    rand_p = np.random.randint(int(p_min*100),int(p_max*100))/100   
    
    g = nx.fast_gnp_random_graph(rand_n,rand_p)    
    node_feat_matrix = np.random.random((rand_n,n_nf))
    
    graphs.append(nx.to_numpy_array(g))
    node_features.append(node_feat_matrix)
    
    labels.append(rand_p)

# %% [markdown]
# We now have three lists of length 100. The graphs list is composed of numpy arrays that represent the adjacency matrix of the graph. The node features list is composed of numpy arrays that contain the node information for each graph. The labels list is a list of integers that corresponds to the class label for each graph.
#
# The next step is to take this data and convert it into an appropriate format for hcga.

# %%
# converting this data into the format required for hcga

from hcga.graph import Graph, GraphCollection

# create graph collection object
g_c = GraphCollection()


# looping over each graph and appending it to the graph collection object
for i,A in enumerate(graphs):
    
    # generating a sparse matrix
    sA = sc.sparse.coo_matrix(A)
    
    # extracting edge list from scipy sparse matrix
    edges = np.array([sA.row,sA.col,sA.data]).T
    
    # passing edge list to pandas dataframe
    edges_df = pd.DataFrame(edges, columns = ['start_node', 'end_node', 'weight'])

    # creating node ids based on size of adjancency matrix
    nodes = np.arange(0,A.shape[0])
    
    # loading node ids into dataframe
    nodes_df = pd.DataFrame(index=nodes)

    # each node should have the same number of node features across all graphs
    # converting node features array to list such that each node is assigned a list.
    nodes_df['attributes'] = node_features[i].tolist()

    # extracting graph label from labels
    graph_label = None
    
    # create a single graph object
    graph = Graph(nodes_df, edges_df, graph_label, 'none')

    # add new graph to the collection
    g_c.add_graph(graph)

# %%
# perform some sanity checks

print('There are {} graphs'.format(len(g_c.graphs)))
print('There are {} features per node'.format(g_c.get_n_node_features()))
# Out:
# There are 50 graphs
# There are 3 features per node

# %%
# we can save this if we want to and run everything from the command line
from hcga.io import save_dataset

save_dataset(g_c, 'custom_dataset_unsupervised', folder='./datasets')

# %% [markdown]
# # Extracting features
#
# We have now produced a pickle dataset of your own custom data. We can now run the feature extraction from the command line using the following commands:
#
# hcga extract_features ./datasets/custom_dataset.pkl -m fast -n 4 -sl advanced --timeout 10
#
#
# Alternatively,we could import the Hcga class and run the feature extraction and analysis from within the notebook. We will do this below.

# %%
from hcga.io import load_dataset

graphs = load_dataset('./datasets/custom_dataset_unsupervised.pkl')

# %%
#import hcga object
from hcga.hcga import Hcga

# define an object
h = Hcga()

#assigning the graphs field to the recently created dataset
h.graphs = graphs

# %%
# extracting all features here
h.extract(mode='fast',n_workers=4,timeout=2)
# Out:
# Returning the maximal subgraph for each graph
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# An input array is constant; the correlation coefficent is not defined.
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# Extracting features from 50 graphs (we disabled 0 graphs).
# Computing features for 50 graphs:
#   0%|          | 0/50 [00:00<?, ?it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 0 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 0 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature edge betweenness centrality_hmean for graph 0 with exception: Harmonic mean only defined if all elements greater than or equal to zero
# Degrees of freedom <= 0 for slice
# Degrees of freedom <= 0 for slice
# invalid value encountered in true_divide
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 0 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Mean of empty slice.
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature num_communities for graph 0 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature largest_commsize for graph 0 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature ratio_commsize_maxmin for graph 0 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature communities for graph 0 with exception: float division by zero
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature clique_sizes_min for graph 0 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature clique_sizes_max for graph 0 with exception: zero-size array to reduction operation maximum which has no identity
# invalid value encountered in true_divide
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_mode for graph 0 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstat for graph 0 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstatvar for graph 0 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmin for graph 0 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmax for graph 0 with exception: No array values within given limits
# Mean of empty slice.
# DEBUG:Feature exceptions:Failed feature clique_sizes_maximal for graph 0 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_min for graph 0 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_max for graph 0 with exception: zero-size array to reduction operation maximum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_mode for graph 0 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_kstat for graph 0 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_kstatvar for graph 0 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_tmin for graph 0 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature edge_weights_tmax for graph 0 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature rich_club_k=1 for graph 0 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_k=max for graph 0 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_maxminratio for graph 0 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club for graph 0 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff for graph 0 with exception: max() arg is an empty sequence
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff_pearson for graph 0 with exception: not enough values to unpack (expected 2, got 0)
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#   2%|▏         | 1/50 [00:01<01:05,  1.33s/it]divide by zero encountered in log
# divide by zero encountered in double_scalars
#   4%|▍         | 2/50 [00:01<00:46,  1.04it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#   6%|▌         | 3/50 [00:01<00:37,  1.25it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#   8%|▊         | 4/50 [00:02<00:36,  1.26it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in log
# Mean of empty slice.
# invalid value encountered in double_scalars
#  12%|█▏        | 6/50 [00:03<00:27,  1.58it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  14%|█▍        | 7/50 [00:03<00:21,  1.99it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  16%|█▌        | 8/50 [00:04<00:24,  1.74it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  18%|█▊        | 9/50 [00:04<00:21,  1.95it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  20%|██        | 10/50 [00:04<00:19,  2.08it/s]Mean of empty slice.
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  24%|██▍       | 12/50 [00:05<00:16,  2.25it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  26%|██▌       | 13/50 [00:06<00:19,  1.87it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  28%|██▊       | 14/50 [00:06<00:18,  1.93it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  30%|███       | 15/50 [00:07<00:22,  1.55it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature local_efficiency for graph 13 took longer than 2 seconds
#  32%|███▏      | 16/50 [00:08<00:21,  1.61it/s]DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 20 with exception: zero-size array to reduction operation minimum which has no identity
# Degrees of freedom <= 0 for slice
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 20 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature edge betweenness centrality_hmean for graph 20 with exception: Harmonic mean only defined if all elements greater than or equal to zero
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 20 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
#  34%|███▍      | 17/50 [00:08<00:16,  1.98it/s]invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature num_communities for graph 20 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature largest_commsize for graph 20 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature ratio_commsize_maxmin for graph 20 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature communities for graph 20 with exception: float division by zero
# Mean of empty slice.
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_min for graph 20 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature clique_sizes_max for graph 20 with exception: zero-size array to reduction operation maximum which has no identity
# invalid value encountered in true_divide
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_mode for graph 20 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstat for graph 20 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstatvar for graph 20 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmin for graph 20 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmax for graph 20 with exception: No array values within given limits
# Mean of empty slice.
# DEBUG:Feature exceptions:Failed feature clique_sizes_maximal for graph 20 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_min for graph 20 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_max for graph 20 with exception: zero-size array to reduction operation maximum which has no identity
#  36%|███▌      | 18/50 [00:09<00:17,  1.83it/s]DEBUG:Feature exceptions:Failed feature edge_weights_mode for graph 20 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_kstat for graph 20 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_kstatvar for graph 20 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_tmin for graph 20 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature edge_weights_tmax for graph 20 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature rich_club_k=1 for graph 20 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_k=max for graph 20 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_maxminratio for graph 20 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club for graph 20 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff for graph 20 with exception: max() arg is an empty sequence
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff_pearson for graph 20 with exception: not enough values to unpack (expected 2, got 0)
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# Mean of empty slice.
#  38%|███▊      | 19/50 [00:09<00:18,  1.71it/s]invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  40%|████      | 20/50 [00:11<00:22,  1.33it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 13 took longer than 2 seconds
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  42%|████▏     | 21/50 [00:12<00:26,  1.11it/s]DEBUG:Feature exceptions:Feature local_efficiency for graph 21 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  44%|████▍     | 22/50 [00:13<00:26,  1.05it/s]DEBUG:Feature exceptions:Feature clique_sizes for graph 13 took longer than 2 seconds
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature num_cliques for graph 21 took longer than 2 seconds
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  46%|████▌     | 23/50 [00:15<00:32,  1.19s/it]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in log
#  48%|████▊     | 24/50 [00:15<00:25,  1.03it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Feature clique sizes for graph 13 took longer than 2 seconds
#  50%|█████     | 25/50 [00:16<00:24,  1.01it/s]divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Feature clique_sizes for graph 21 took longer than 2 seconds
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 29 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 29 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
#  52%|█████▏    | 26/50 [00:17<00:20,  1.18it/s]divide by zero encountered in log
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in true_divide
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature edge betweenness centrality_hmean for graph 29 with exception: Harmonic mean only defined if all elements greater than or equal to zero
# invalid value encountered in true_divide
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 29 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
#  54%|█████▍    | 27/50 [00:17<00:16,  1.43it/s]DEBUG:Feature exceptions:Failed feature num_communities for graph 29 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature largest_commsize for graph 29 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature ratio_commsize_maxmin for graph 29 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature communities for graph 29 with exception: float division by zero
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature clique_sizes_min for graph 29 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature clique_sizes_max for graph 29 with exception: zero-size array to reduction operation maximum which has no identity
# invalid value encountered in true_divide
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_mode for graph 29 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstat for graph 29 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstatvar for graph 29 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmin for graph 29 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmax for graph 29 with exception: No array values within given limits
# Mean of empty slice.
# DEBUG:Feature exceptions:Failed feature clique_sizes_maximal for graph 29 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_min for graph 29 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_max for graph 29 with exception: zero-size array to reduction operation maximum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_mode for graph 29 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature edge_weights_kstat for graph 29 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_kstatvar for graph 29 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_tmin for graph 29 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature edge_weights_tmax for graph 29 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature rich_club_k=1 for graph 29 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_k=max for graph 29 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_maxminratio for graph 29 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club for graph 29 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff for graph 29 with exception: max() arg is an empty sequence
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff_pearson for graph 29 with exception: not enough values to unpack (expected 2, got 0)
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  58%|█████▊    | 29/50 [00:18<00:11,  1.83it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  64%|██████▍   | 32/50 [00:20<00:12,  1.43it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  66%|██████▌   | 33/50 [00:21<00:13,  1.29it/s]DEBUG:Feature exceptions:Feature local_efficiency for graph 31 took longer than 2 seconds
#  68%|██████▊   | 34/50 [00:21<00:10,  1.53it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# divide by zero encountered in log
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  70%|███████   | 35/50 [00:23<00:14,  1.05it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  72%|███████▏  | 36/50 [00:23<00:10,  1.28it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 40 with exception: zero-size array to reduction operation minimum which has no identity
# invalid value encountered in double_scalars
# divide by zero encountered in log
# invalid value encountered in double_scalars
#  74%|███████▍  | 37/50 [00:23<00:07,  1.65it/s]invalid value encountered in true_divide
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 40 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# An input array is constant; the correlation coefficent is not defined.
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
#  76%|███████▌  | 38/50 [00:24<00:08,  1.36it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  78%|███████▊  | 39/50 [00:25<00:06,  1.61it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
#  80%|████████  | 40/50 [00:25<00:06,  1.67it/s]divide by zero encountered in double_scalars
# Mean of empty slice.
# divide by zero encountered in double_scalars
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature minimum_cycle_length for graph 44 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature min_edge_cover for graph 44 with exception: Graph has a node with no edge incident on it, so no edge cover exists.
#  82%|████████▏ | 41/50 [00:26<00:05,  1.68it/s]divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature edge betweenness centrality_hmean for graph 44 with exception: Harmonic mean only defined if all elements greater than or equal to zero
# invalid value encountered in true_divide
# Degrees of freedom <= 0 for slice
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
# DEBUG:Feature exceptions:Failed feature eigenvector centrality for graph 44 with exception: Cannot use scipy.linalg.eig for sparse A with k >= N - 1. Use scipy.linalg.eig(A.toarray()) or reduce k.
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# invalid value encountered in double_scalars
# Degrees of freedom <= 0 for slice
# Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature num_communities for graph 44 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature largest_commsize for graph 44 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature ratio_commsize_maxmin for graph 44 with exception: float division by zero
# DEBUG:Feature exceptions:Failed feature communities for graph 44 with exception: float division by zero
# divide by zero encountered in log
# invalid value encountered in double_scalars
# invalid value encountered in true_divide
# DEBUG:Feature exceptions:Failed feature clique_sizes_min for graph 44 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature clique_sizes_max for graph 44 with exception: zero-size array to reduction operation maximum which has no identity
# invalid value encountered in true_divide
# Mean of empty slice.
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature clique_sizes_mode for graph 44 with exception: index 0 is out of bounds for axis 0 with size 0
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstat for graph 44 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_kstatvar for graph 44 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmin for graph 44 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature clique_sizes_tmax for graph 44 with exception: No array values within given limits
# Mean of empty slice.
# DEBUG:Feature exceptions:Failed feature clique_sizes_maximal for graph 44 with exception: index 0 is out of bounds for axis 0 with size 0
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature edge_weights_min for graph 44 with exception: zero-size array to reduction operation minimum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_max for graph 44 with exception: zero-size array to reduction operation maximum which has no identity
# DEBUG:Feature exceptions:Failed feature edge_weights_mode for graph 44 with exception: index 0 is out of bounds for axis 0 with size 0
# invalid value encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature edge_weights_kstat for graph 44 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_kstatvar for graph 44 with exception: Data input must not be empty
# DEBUG:Feature exceptions:Failed feature edge_weights_tmin for graph 44 with exception: No array values within given limits
# divide by zero encountered in double_scalars
# DEBUG:Feature exceptions:Failed feature edge_weights_tmax for graph 44 with exception: No array values within given limits
# DEBUG:Feature exceptions:Failed feature rich_club_k=1 for graph 44 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_k=max for graph 44 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club_maxminratio for graph 44 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature rich_club for graph 44 with exception: pop from empty list
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff for graph 44 with exception: max() arg is an empty sequence
# DEBUG:Feature exceptions:Failed feature degree_assortativity_coeff_pearson for graph 44 with exception: not enough values to unpack (expected 2, got 0)
# divide by zero encountered in double_scalars
#  86%|████████▌ | 43/50 [00:27<00:03,  1.76it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  90%|█████████ | 45/50 [00:27<00:02,  2.19it/s]Mean of empty slice.
# invalid value encountered in double_scalars
#  92%|█████████▏| 46/50 [00:28<00:01,  2.10it/s]Mean of empty slice.
# invalid value encountered in double_scalars
# Mean of empty slice.
# invalid value encountered in double_scalars
# divide by zero encountered in double_scalars
#  94%|█████████▍| 47/50 [00:29<00:02,  1.43it/s]divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
#  98%|█████████▊| 49/50 [00:30<00:00,  1.57it/s]DEBUG:Feature exceptions:Feature local_efficiency for graph 48 took longer than 2 seconds
# DEBUG:Feature exceptions:Feature num_cliques for graph 48 took longer than 2 seconds
# divide by zero encountered in double_scalars
# 100%|██████████| 50/50 [00:35<00:00,  1.40it/s]
# 628 feature extracted.
# 350 valid features.

# %%
# saving all features into a pickle
h.save_features('./results/custom_dataset_unsupervised/all_features.pkl')

# %% [markdown]
# # Analysis - regression  example

# %%
# load the saved features

h.load_features('./results/custom_dataset_unsupervised/all_features.pkl')

# %%
# implement a classification analyse of the features
h.analyse_features(feature_file='./results/custom_dataset_unsupervised/all_features.pkl',
                   analysis_type='unsupervised',
                   results_folder='./results/custom_dataset_unsupervised')
# Out:
# INFO:hcga.analysis:628 total features
# INFO:hcga.utils:2 graphs were removed for more than 0.3 fraction of bad features
# INFO:hcga.analysis:416 valid features
# INFO:hcga.analysis:416 with interpretability 1
# Variance of PC component 1: 0.365368005637843
# Variance of PC component 2: 0.2281457582944256
