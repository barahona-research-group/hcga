# %% [markdown]
# # Example: Molecule dataset
#
# Here we show a real-world example where we download a molecule dataset where the graphs include energy based measures such as band gap or physical measures such as shear and bulk moduli.

# %%
import pandas as pd
import numpy as np
import json
import networkx as nx
import matplotlib.pyplot as plt
import signal
import scipy as sc

import urllib.request
import os
from pathlib import Path

# %% [markdown]
# ## Download the dataset
#
# NOTE: If the below cell does not work then please download directly from https://figshare.com/articles/Graphs_of_materials_project/7451351 and place into a folder of your choosing.

# %%
# load molecules from https://figshare.com/articles/Graphs_of_materials_project/7451351

folder = "./datasets/molecules"
if not Path(folder).exists():
    os.mkdir(folder)  
    
urllib.request.urlretrieve("https://ndownloader.figshare.com/files/15087992", "./datasets/molecules/molecules.json")

# %% [markdown]
# ## Load the data into python

# %%
with open('./datasets/molecules/mp.2018.6.1.json') as json_file:
    data = json.load(json_file)

# %% [markdown]
# Since the dataset is quite large and this is an example, the next cell filters out those molecules that don't have a bulk and shear moduli label.

# %%
# only look at molecules with bulk and shear moduli available       
mols = []
for mol in data:
    if 'G' in list(mol.keys()):
        mols.append(mol)

# %% [markdown]
# # Graph construction from raw data

# %%
#  construct graph from bond energies
data = []    

keys = set(x for l in mols for x in l)

G = np.zeros(len(mols))
K = np.zeros(len(mols))
band_gap = np.zeros(len(mols))
formation_energy = np.zeros(len(mols))
G[:] = np.nan
K[:] = np.nan
band_gap[:] = np.nan
formation_energy[:] = np.nan

labels = []
graphs = []
node_features = []

for i,mol in enumerate(mols):
    graph = mol['graph']    
    edges = pd.DataFrame(columns=['source','target','weight'])
    edges['source'] = graph['index1']
    edges['target'] = graph['index2']
    edges['weight'] = graph['bond']
    edges = edges.groupby(['source','target']).sum()
    edges.reset_index(level=1, inplace=True)
    edges.reset_index(level=0, inplace=True)
    g = nx.from_pandas_edgelist(edges, edge_attr=True)
    
   
    # get node features (N x f)
    node_feats = np.asarray(graph['atom'])
    node_feat_matrix = np.zeros((node_feats.size, 100))
    node_feat_matrix[np.arange(node_feats.size),node_feats] = 1

    
    # append to graphs list
    graphs.append(g)
    labels.append(mol['band_gap'])
    node_features.append(node_feat_matrix)

    #G[i] = mol['G']
    #K[i] = mol['K']
    #band_gap[i] = mol['band_gap']
    #formation_energy[i] = mol['formation_energy_per_atom']

# %% [markdown]
# ## Load into graph object for hcga

# %%
# converting this data into the format required for hcga

from hcga.graph import Graph, GraphCollection

# create graph collection object
g_c = GraphCollection()

# add graphs, node features and labels to the object
g_c.add_graph_list(graphs,node_features,labels)

# %%
# perform some sanity checks

print('There are {} graphs'.format(len(g_c.graphs)))
print('There are {} features per node'.format(g_c.get_n_node_features()))
# Out:
# There are 5830 graphs
# There are 100 features per node

# %%
# we can save this if we want to and run everything from the command line
from hcga.io import save_dataset
save_dataset(g_c, 'molecules', folder='./datasets/molecules/')

# %% [markdown]
# # Extracting features

# %%
#import hcga object
from hcga.hcga import Hcga

# define an object
h = Hcga()

# load previously saved dataset
h.load_data('./datasets/molecules/molecules.pkl')

# %%
# extracting all features here
h.extract(mode='fast',n_workers=4,timeout=5)

# saving all features into a pickle
h.save_features('./results/molecules/all_features.pkl')
# Out:
# INFO:hcga.extraction:Extracting features from 5475 graphs (we disabled 355 graphs).
# INFO:hcga.extraction:Computing features for 5475 graphs:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=4)]: Done 105 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=4)]: Done 137 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=4)]: Done 173 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=4)]: Done 213 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=4)]: Done 234 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=4)]: Done 257 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=4)]: Done 305 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=4)]: Done 330 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=4)]: Done 357 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=4)]: Done 384 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=4)]: Done 413 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=4)]: Done 473 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=4)]: Done 537 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=4)]: Done 570 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=4)]: Done 605 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=4)]: Done 640 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=4)]: Done 677 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=4)]: Done 714 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=4)]: Done 753 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed: 25.7min
# [Parallel(n_jobs=4)]: Done 833 tasks      | elapsed: 27.0min
# [Parallel(n_jobs=4)]: Done 874 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=4)]: Done 917 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=4)]: Done 960 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=4)]: Done 1005 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=4)]: Done 1050 tasks      | elapsed: 34.7min
# [Parallel(n_jobs=4)]: Done 1097 tasks      | elapsed: 36.4min
# [Parallel(n_jobs=4)]: Done 1144 tasks      | elapsed: 38.5min
# [Parallel(n_jobs=4)]: Done 1193 tasks      | elapsed: 40.7min
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed: 42.9min
# [Parallel(n_jobs=4)]: Done 1293 tasks      | elapsed: 45.1min
# [Parallel(n_jobs=4)]: Done 1344 tasks      | elapsed: 47.4min
# [Parallel(n_jobs=4)]: Done 1397 tasks      | elapsed: 49.8min
# [Parallel(n_jobs=4)]: Done 1450 tasks      | elapsed: 52.2min
# [Parallel(n_jobs=4)]: Done 1505 tasks      | elapsed: 54.0min
# [Parallel(n_jobs=4)]: Done 1560 tasks      | elapsed: 55.8min
# [Parallel(n_jobs=4)]: Done 1617 tasks      | elapsed: 57.7min
# [Parallel(n_jobs=4)]: Done 1674 tasks      | elapsed: 59.6min
# [Parallel(n_jobs=4)]: Done 1733 tasks      | elapsed: 61.7min
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed: 63.7min
# [Parallel(n_jobs=4)]: Done 1853 tasks      | elapsed: 65.8min
# [Parallel(n_jobs=4)]: Done 1914 tasks      | elapsed: 67.9min
# [Parallel(n_jobs=4)]: Done 1977 tasks      | elapsed: 70.0min
# [Parallel(n_jobs=4)]: Done 2040 tasks      | elapsed: 72.1min
# [Parallel(n_jobs=4)]: Done 2105 tasks      | elapsed: 74.1min
# [Parallel(n_jobs=4)]: Done 2170 tasks      | elapsed: 76.2min
# [Parallel(n_jobs=4)]: Done 2237 tasks      | elapsed: 78.4min
# [Parallel(n_jobs=4)]: Done 2304 tasks      | elapsed: 80.5min
# [Parallel(n_jobs=4)]: Done 2373 tasks      | elapsed: 82.7min
# [Parallel(n_jobs=4)]: Done 2442 tasks      | elapsed: 84.8min
# [Parallel(n_jobs=4)]: Done 2513 tasks      | elapsed: 87.2min
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed: 89.6min
# [Parallel(n_jobs=4)]: Done 2657 tasks      | elapsed: 92.0min
# [Parallel(n_jobs=4)]: Done 2730 tasks      | elapsed: 94.3min
# [Parallel(n_jobs=4)]: Done 2805 tasks      | elapsed: 96.7min
# [Parallel(n_jobs=4)]: Done 2880 tasks      | elapsed: 99.3min
# [Parallel(n_jobs=4)]: Done 2957 tasks      | elapsed: 101.8min
# [Parallel(n_jobs=4)]: Done 3034 tasks      | elapsed: 104.6min
# [Parallel(n_jobs=4)]: Done 3113 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed: 110.7min
# [Parallel(n_jobs=4)]: Done 3273 tasks      | elapsed: 113.9min
# [Parallel(n_jobs=4)]: Done 3354 tasks      | elapsed: 117.1min
# [Parallel(n_jobs=4)]: Done 3437 tasks      | elapsed: 119.7min
# [Parallel(n_jobs=4)]: Done 3520 tasks      | elapsed: 122.4min
# [Parallel(n_jobs=4)]: Done 3605 tasks      | elapsed: 125.4min
# [Parallel(n_jobs=4)]: Done 3690 tasks      | elapsed: 128.5min
# [Parallel(n_jobs=4)]: Done 3777 tasks      | elapsed: 131.4min
# [Parallel(n_jobs=4)]: Done 3864 tasks      | elapsed: 134.5min
# [Parallel(n_jobs=4)]: Done 3953 tasks      | elapsed: 138.3min
# [Parallel(n_jobs=4)]: Done 4042 tasks      | elapsed: 141.6min
# [Parallel(n_jobs=4)]: Done 4133 tasks      | elapsed: 144.8min
# [Parallel(n_jobs=4)]: Done 4224 tasks      | elapsed: 148.2min
# [Parallel(n_jobs=4)]: Done 4317 tasks      | elapsed: 151.3min
# [Parallel(n_jobs=4)]: Done 4410 tasks      | elapsed: 154.8min
# [Parallel(n_jobs=4)]: Done 4505 tasks      | elapsed: 158.1min
# [Parallel(n_jobs=4)]: Done 4600 tasks      | elapsed: 161.3min
# [Parallel(n_jobs=4)]: Done 4697 tasks      | elapsed: 164.5min
# [Parallel(n_jobs=4)]: Done 4794 tasks      | elapsed: 167.6min
# [Parallel(n_jobs=4)]: Done 4893 tasks      | elapsed: 170.9min
# [Parallel(n_jobs=4)]: Done 4992 tasks      | elapsed: 174.9min
# [Parallel(n_jobs=4)]: Done 5093 tasks      | elapsed: 178.6min
# [Parallel(n_jobs=4)]: Done 5194 tasks      | elapsed: 182.4min
# [Parallel(n_jobs=4)]: Done 5297 tasks      | elapsed: 185.9min
# [Parallel(n_jobs=4)]: Done 5400 tasks      | elapsed: 190.3min
# [Parallel(n_jobs=4)]: Done 5475 out of 5475 | elapsed: 193.5min finished

# %% [markdown]
# ## Analysis
#
# Here we perform a regression of the extracted features against bandgap (this label can be changed).

# %%
# load the saved features

h.load_features('./results/molecules/all_features.pkl')

# %%
# implement a regression analyse of the features
h.analyse_features(feature_file='./results/molecules/all_features.pkl',
                   results_folder='./results/molecules')
# Out:
# INFO:hcga.analysis:2727 total features
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:hcga.utils:0 graphs were removed for more than 0.3 fraction of bad features
# INFO:hcga.analysis:1652 valid features
# INFO:hcga.analysis:1652 with interpretability 1
# INFO:hcga.analysis:... Using Xgboost regressor ...
# INFO:hcga.analysis:Using kfold
# INFO:hcga.analysis:Mean Absolute Error: --- 0.491 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.458 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.49 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.436 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.47 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.478 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.449 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.457 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.439 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.446 ---
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO:hcga.analysis:Mean absolute error: 0.461 +/- 0.019
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# INFO:hcga.analysis:Now using a reduced set of 101 features with < 0.9 correlation.
# INFO:hcga.analysis:Mean Absolute Error: --- 0.512 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.468 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.512 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.463 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.446 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.462 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.47 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.466 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.455 ---
# INFO:hcga.analysis:Mean Absolute Error: --- 0.447 ---
# INFO:hcga.analysis:Mean Absolute Error with reduced set: 0.47 +/- 0.022
# Sample Expanded Feature Summary for Class 0
